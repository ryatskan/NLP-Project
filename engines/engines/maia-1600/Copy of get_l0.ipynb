# %%
# !git clone -b release/0.29 --recurse-submodules https://github.com/LeelaChessZero/lc0.git
# Out:
# Cloning into 'lc0'...
# remote: Enumerating objects: 10726, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 10726 (delta 62), reused 80 (delta 38), pack-reused 10600
# Receiving objects: 100% (10726/10726), 38.42 MiB | 13.14 MiB/s, done.
# Resolving deltas: 100% (7655/7655), done.
# Submodule 'libs/lczero-common' (https://github.com/LeelaChessZero/lczero-common.git) registered for path 'libs/lczero-common'
# Cloning into '/content/lc0/libs/lczero-common'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 169 (delta 6), reused 24 (delta 4), pack-reused 140
# Receiving objects: 100% (169/169), 33.73 KiB | 767.00 KiB/s, done.
# Resolving deltas: 100% (50/50), done.
# Submodule path 'libs/lczero-common': checked out '4dfa4ce8339357819f7de01517e6297d4c768cdf'

# %%
# !sudo apt-get install libstdc++-8-dev clang-6.0 ninja-build pkg-config
# !pip3 install meson --user
# !CC=clang-6.0 CXX=clang++-6.0 INSTALL_PREFIX=~/.local ./build.sh
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pkg-config is already the newest version (0.29.1-0ubuntu4).
# The following additional packages will be installed:
#   binfmt-support gcc-8-base libclang-common-6.0-dev libclang1-6.0 libffi-dev
#   libgcc-8-dev libllvm6.0 libmpx2 libomp-10-dev libomp-dev libomp5-10
#   libpython2-stdlib llvm-6.0 llvm-6.0-dev llvm-6.0-runtime python2
#   python2-minimal
# Suggested packages:
#   gnustep gnustep-devel libomp-10-doc libstdc++-8-doc python2-doc python-tk
# The following NEW packages will be installed:
#   binfmt-support clang-6.0 gcc-8-base libclang-common-6.0-dev libclang1-6.0
#   libffi-dev libgcc-8-dev libllvm6.0 libmpx2 libomp-10-dev libomp-dev
#   libomp5-10 libpython2-stdlib libstdc++-8-dev llvm-6.0 llvm-6.0-dev
#   llvm-6.0-runtime ninja-build python2 python2-minimal
# 0 upgraded, 20 newly installed, 0 to remove and 38 not upgraded.
# Need to get 69.1 MB of archives.
# After this operation, 396 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2-minimal amd64 2.7.17-2ubuntu4 [27.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpython2-stdlib amd64 2.7.17-2ubuntu4 [7,072 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2 amd64 2.7.17-2ubuntu4 [26.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 binfmt-support amd64 2.2.0-2 [58.2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libllvm6.0 amd64 1:6.0.1-14 [15.2 MB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 libclang-common-6.0-dev amd64 1:6.0.1-14 [3,015 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 libclang1-6.0 amd64 1:6.0.1-14 [7,472 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/universe amd64 clang-6.0 amd64 1:6.0.1-14 [9,831 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/universe amd64 gcc-8-base amd64 8.4.0-3ubuntu2 [18.7 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmpx2 amd64 8.4.0-3ubuntu2 [11.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgcc-8-dev amd64 8.4.0-3ubuntu2 [2,313 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/universe amd64 libomp5-10 amd64 1:10.0.0-4ubuntu1 [300 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/universe amd64 libomp-10-dev amd64 1:10.0.0-4ubuntu1 [47.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/universe amd64 libstdc++-8-dev amd64 8.4.0-3ubuntu2 [1,537 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/universe amd64 llvm-6.0-runtime amd64 1:6.0.1-14 [207 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/universe amd64 llvm-6.0 amd64 1:6.0.1-14 [4,889 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 libffi-dev amd64 3.3-4 [57.0 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/universe amd64 llvm-6.0-dev amd64 1:6.0.1-14 [24.0 MB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/universe amd64 ninja-build amd64 1.10.0-1build1 [107 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/universe amd64 libomp-dev amd64 1:10.0-50~exp1 [2,824 B]
# Fetched 69.1 MB in 9s (7,783 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 20.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python2-minimal.
# (Reading database ... 122541 files and directories currently installed.)
# Preparing to unpack .../python2-minimal_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package libpython2-stdlib:amd64.
# Preparing to unpack .../libpython2-stdlib_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package python2.
# (Reading database ... 122570 files and directories currently installed.)
# Preparing to unpack .../00-python2_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2 (2.7.17-2ubuntu4) ...
# Selecting previously unselected package binfmt-support.
# Preparing to unpack .../01-binfmt-support_2.2.0-2_amd64.deb ...
# Unpacking binfmt-support (2.2.0-2) ...
# Selecting previously unselected package libllvm6.0:amd64.
# Preparing to unpack .../02-libllvm6.0_1%3a6.0.1-14_amd64.deb ...
# Unpacking libllvm6.0:amd64 (1:6.0.1-14) ...
# Selecting previously unselected package libclang-common-6.0-dev.
# Preparing to unpack .../03-libclang-common-6.0-dev_1%3a6.0.1-14_amd64.deb ...
# Unpacking libclang-common-6.0-dev (1:6.0.1-14) ...
# Selecting previously unselected package libclang1-6.0.
# Preparing to unpack .../04-libclang1-6.0_1%3a6.0.1-14_amd64.deb ...
# Unpacking libclang1-6.0 (1:6.0.1-14) ...
# Selecting previously unselected package clang-6.0.
# Preparing to unpack .../05-clang-6.0_1%3a6.0.1-14_amd64.deb ...
# Unpacking clang-6.0 (1:6.0.1-14) ...
# Selecting previously unselected package gcc-8-base:amd64.
# Preparing to unpack .../06-gcc-8-base_8.4.0-3ubuntu2_amd64.deb ...
# Unpacking gcc-8-base:amd64 (8.4.0-3ubuntu2) ...
# Selecting previously unselected package libmpx2:amd64.
# Preparing to unpack .../07-libmpx2_8.4.0-3ubuntu2_amd64.deb ...
# Unpacking libmpx2:amd64 (8.4.0-3ubuntu2) ...
# Selecting previously unselected package libgcc-8-dev:amd64.
# Preparing to unpack .../08-libgcc-8-dev_8.4.0-3ubuntu2_amd64.deb ...
# Unpacking libgcc-8-dev:amd64 (8.4.0-3ubuntu2) ...
# Selecting previously unselected package libomp5-10:amd64.
# Preparing to unpack .../09-libomp5-10_1%3a10.0.0-4ubuntu1_amd64.deb ...
# Unpacking libomp5-10:amd64 (1:10.0.0-4ubuntu1) ...
# Selecting previously unselected package libomp-10-dev.
# Preparing to unpack .../10-libomp-10-dev_1%3a10.0.0-4ubuntu1_amd64.deb ...
# Unpacking libomp-10-dev (1:10.0.0-4ubuntu1) ...
# Selecting previously unselected package libstdc++-8-dev:amd64.
# Preparing to unpack .../11-libstdc++-8-dev_8.4.0-3ubuntu2_amd64.deb ...
# Unpacking libstdc++-8-dev:amd64 (8.4.0-3ubuntu2) ...
# Selecting previously unselected package llvm-6.0-runtime.
# Preparing to unpack .../12-llvm-6.0-runtime_1%3a6.0.1-14_amd64.deb ...
# Unpacking llvm-6.0-runtime (1:6.0.1-14) ...
# Selecting previously unselected package llvm-6.0.
# Preparing to unpack .../13-llvm-6.0_1%3a6.0.1-14_amd64.deb ...
# Unpacking llvm-6.0 (1:6.0.1-14) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../14-libffi-dev_3.3-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.3-4) ...
# Selecting previously unselected package llvm-6.0-dev.
# Preparing to unpack .../15-llvm-6.0-dev_1%3a6.0.1-14_amd64.deb ...
# Unpacking llvm-6.0-dev (1:6.0.1-14) ...
# Selecting previously unselected package ninja-build.
# Preparing to unpack .../16-ninja-build_1.10.0-1build1_amd64.deb ...
# Unpacking ninja-build (1.10.0-1build1) ...
# Selecting previously unselected package libomp-dev.
# Preparing to unpack .../17-libomp-dev_1%3a10.0-50~exp1_amd64.deb ...
# Unpacking libomp-dev (1:10.0-50~exp1) ...
# Setting up libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up libffi-dev:amd64 (3.3-4) ...
# Setting up libllvm6.0:amd64 (1:6.0.1-14) ...
# Setting up python2 (2.7.17-2ubuntu4) ...
# Setting up libclang1-6.0 (1:6.0.1-14) ...
# Setting up ninja-build (1.10.0-1build1) ...
# Setting up gcc-8-base:amd64 (8.4.0-3ubuntu2) ...
# Setting up binfmt-support (2.2.0-2) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/binfmt-support.service → /lib/systemd/system/binfmt-support.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libmpx2:amd64 (8.4.0-3ubuntu2) ...
# Setting up llvm-6.0-runtime (1:6.0.1-14) ...
# Setting up libomp5-10:amd64 (1:10.0.0-4ubuntu1) ...
# Setting up libomp-10-dev (1:10.0.0-4ubuntu1) ...
# Setting up llvm-6.0 (1:6.0.1-14) ...
# Setting up libclang-common-6.0-dev (1:6.0.1-14) ...
# Setting up llvm-6.0-dev (1:6.0.1-14) ...
# Setting up libgcc-8-dev:amd64 (8.4.0-3ubuntu2) ...
# Setting up clang-6.0 (1:6.0.1-14) ...
# Setting up libomp-dev (1:10.0-50~exp1) ...
# Setting up libstdc++-8-dev:amd64 (8.4.0-3ubuntu2) ...
# Processing triggers for systemd (245.4-4ubuntu3.21) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting meson
#   Downloading meson-1.1.1-py3-none-any.whl (918 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 918.4/918.4 kB 13.4 MB/s eta 0:00:00
# Installing collected packages: meson
#   WARNING: The script meson is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed meson-1.1.1
# /bin/bash: ./build.sh: No such file or directory
